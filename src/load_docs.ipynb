# %%
import os
from os.path import join
import json

dir_json = join(os.path.expanduser('~'),'cs671project/data/pre_process_labeled_data.json')
with open(dir_json) as f:
    doc_json = json.loads(f.read())

# %%
intro = dict()

for key, value in doc_json.items():
    intro[key] = value['introduction']

# %%
intro
# Out:
# {'A00-1020': ['conclusions',
#   'recent availability large bilingual corpora spawned interest several areas multilingual text processing',
#   'research focused bilingual terminology identification either par allel multiwords forms eg champollion sys tem smadja et al1996 technical terminology eg termight system dagan church broadcoverage translation lexicons eg sable system resnik melamed',
#   'addition multilingual entity task met tip ster program1 httpwwwnlpirnistgovjrelated projectsjtipsterjmethtm challenged partici pants message understanding conference muc extract named entities several eign language corpora chinese japanese spanish',
#   'paper present new application aligned multilingual texts',
#   'since coreference reso lution pervasive discourse phenomenon causing performance impediments current ie systems considered corpus aligned english roma nian texts identify coreferring expressions',
# ...

# %%
import os
from os.path import join
import json

dir_json = join(os.path.expanduser('~'),'cs671project/data/data.json')
with open(dir_json) as f:
    doc_json = json.loads(f.read())

# %%
titles = []
intros = []
abstracts = []
for doc_id, content in doc_json.items():
    titles.append(content['title'][0])
    abstracts.append(content['abstract'])
    intros.append(content['inroduction'])
