# %%
from modules.data import Documents
import modules.beam_search as bs

doc_file = './data/kaggle_news_rouge1.pkl'
docs = Documents(doc_file, vocab_size = 30000)
vocab = docs.vocab

# %%
from modules.texts import Vocab, GloVeLoader
import os
from os.path import join
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import modules.extractive as ext
import modules.abstractive as abs
import modules.beam_search as bs
from modules.data import Documents
from torch.utils.data import DataLoader
import numpy as np

d = 200
emb = nn.Embedding(vocab.V, d)
pretrained = emb
vocab_size = vocab.V
emb_size = emb.weight.data.size(1)
n_kernels = 50
kernel_sizes = [1,2,3,4,5]
sent_size = len(kernel_sizes) * n_kernels
hidden_size = 400
num_layers = 1
n_classes = len(docs.dclass2id)
batch_size = 1
torch.manual_seed(7)
torch.cuda.manual_seed(7)

ext_s_enc = ext.SentenceEncoder(vocab_size, emb_size,
                                   n_kernels, kernel_sizes, pretrained)
ext_d_enc = ext.DocumentEncoder(sent_size, hidden_size)
ext_extc = ext.ExtractorCell(sent_size, hidden_size)
ext_d_classifier = ext.DocumentClassifier(sent_size, n_classes)
abs_enc = abs.EncoderRNN(emb, hidden_size, num_layers)
abs_dec = abs.AttnDecoderRNN(emb, hidden_size * 2, num_layers)

# Load the models
prefix = 'hidden400nkernels50epoch10_'
data_dir = join(os.path.expanduser('~'), 'cs671-large')
models = [emb, ext_s_enc, ext_d_enc, ext_extc, ext_d_classifier, abs_enc, abs_dec]
names = ['emb', 'ext_s_enc','ext_d_enc','ext_extc','ext_d_classifier','abs_enc','abs_dec']
for name, model in zip(names, models):
    model.load_state_dict(torch.load(join(data_dir, prefix + name)))

# %%
from rouge import Rouge

rouge = Rouge()

examples = []
n_samples = 3000
for i, doc in enumerate(docs):
    # start from testing samples
    if i < n_samples: pass
    try:
        test_input = [torch.LongTensor(sent).view(1,-1) for sent in doc.sents]
        ref_input = torch.LongTensor(doc.head).view(1,-1)
        top1_batch, seqs_batch = bs.generate_title(doc_sents = test_input,
                                                   beam_size = 20,
                                                   models = models,
                                                   max_kernel_size = max(ext_s_enc.kernel_sizes))
        for i in range(len(top1_batch)):
            generated = '_BEGIN_ ' + vocab.id2sents([top1_batch[i][0]])
            title = vocab.id2sents([ref_input[i]])
            contents = vocab.id2sents(doc.sents)
            rouge_batch = rouge.get_scores(generated, title)[0]['rouge-1']['r']
            examples.append((generated, title, contents, rouge_batch))
    
    except Exception as e:
        pass
#         print(e)

# %%
f = open('./data/generated_examples_epoch100_recall.txt', 'w')
for generated, title, contents, r_score in sorted(examples, key = lambda x: -x[-1]):
#     if 'firewall' in reference:
#         print(generated)
#         print(reference)
#         print(r_score)
    print(generated)
    print(title)
    print(r_score)
    s = '%s\n%s\n%s\n%.3f\n' % (generated, title, contents, r_score)
    f.write(s)
f.close()

import pickle
with open('./data/generated_examples_epoch100_recall.pkl', 'wb') as f:
    pickle.dump(examples, f)
# Out:
# _BEGIN_ ' fitbits :# reports _END_
# _BEGIN_ bmw denies reports of emissions UNK _END_
# 0.375
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ amul releases poster on ' dangal ' _END_
# 0.375
# _BEGIN_ ' officer its reports _END_
# _BEGIN_ tharoor ' categorically ' denies reports of him joining bjp _END_
# 0.36363636363636365
# _BEGIN_ ' navtej _END_
# _BEGIN_ aamir khan ' s ' dangal ' leaked online _END_
# 0.3333333333333333
# _BEGIN_ ' navtej _END_
# _BEGIN_ mumbai ' s juhu beach to be redeveloped _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ woman sexually assaulted by ' superhost ' sues airbnb _END_
# 0.3
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ release date of ' wonder woman ' sequel announced _END_
# 0.3
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ kargil was india ' s first televised war _END_
# 0.3
# _BEGIN_ gondia ' labs -? dayanand _END_
# _BEGIN_ ' lipstick under my burkha ' hits the theatres _END_
# 0.3
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ makeshift ' illegal ' shops demolished by noida authority _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ trump orders republicans to ' let obamacare fail ' _END_
# 0.3
# _BEGIN_ ' leanings :# reports _END_
# _BEGIN_ jnu students protest disciplinary action over ' activism ' _END_
# 0.3
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ islamic preacher zakir naik ' s passport revoked _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ gorkhaland supporter killed in ' police firing ' in darjeeling _END_
# 0.3
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ bengaluru ' s bellandur lake catches fire again _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ panneerselvam orders probe into jayalalithaa ' s death _END_
# 0.3
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ soapy ' shower beer ' created by swedish brewery _END_
# 0.3
# _BEGIN_ srinu ' _END_
# _BEGIN_ gurugram UNK association identifies ' dog poop thrower ' _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ beyoncé named 2016 ' s most charitable celebrity _END_
# 0.3
# _BEGIN_ srinu ' _END_
# _BEGIN_ uber ceo announces scholarship for baby named ' uber ' _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ schumacher ' s family launches ' keep fighting ' initiative _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ 13th ' santa speedo run ' held in budapest _END_
# 0.3
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ colombia ' s cocaine production reaches record high _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ mercedes ' valtteri bottas wins austrian grand prix _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ soundarya rajinikanth and ashwin ' s divorce finalised _END_
# 0.3
# _BEGIN_ srinu ' _END_
# _BEGIN_ world ' s largest aircraft completes test flight _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ ' doomsday ' vault flooded after surrounding soil UNK _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ chinese folk medicines inspire new ' molecular condoms ' _END_
# 0.3
# _BEGIN_ azmi ' _END_
# _BEGIN_ ' baahubali 2 ' producer accuses emirates of racism _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ raveena tandon ' s ' maatr ' hits the theatres _END_
# 0.3
# _BEGIN_ ' trans :# reports _END_
# _BEGIN_ anushka sharma ' s ' phillauri ' hits the theatres _END_
# 0.3
# _BEGIN_ ' navtej _END_
# _BEGIN_ rajkummar rao starrer ' trapped ' hits the theatres _END_
# 0.3
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ maharashtra government considers relocating tigers _END_
# 0.2857142857142857
# _BEGIN_ srinu ' _END_
# _BEGIN_ istanbul nightclub massacre suspect captured _END_
# 0.2857142857142857
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ indian national arrested in pakistan _END_
# 0.2857142857142857
# _BEGIN_ ' navtej _END_
# _BEGIN_ underwater treasure found in china _END_
# 0.2857142857142857
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ ' virgin ' now corrected to ' unmarried ' in igims ' form _END_
# 0.2727272727272727
# _BEGIN_ ' navtej _END_
# _BEGIN_ congress opens ' state bank of tomato ' in lucknow _END_
# 0.2727272727272727
# _BEGIN_ ' navtej _END_
# _BEGIN_ baby ' pregnant ' with UNK twin born in maharashtra _END_
# 0.2727272727272727
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ release of shraddha kapoor ' s ' haseena parkar ' postponed _END_
# 0.2727272727272727
# _BEGIN_ ' navtej _END_
# _BEGIN_ woman bites off her alleged rapist ' s tongue _END_
# 0.2727272727272727
# _BEGIN_ mandatorily ' ryanair picked _END_
# _BEGIN_ censor board orders 48 cuts in ' babumoshai bandookbaaz ' _END_
# 0.2727272727272727
# _BEGIN_ ' navtej _END_
# _BEGIN_ ferrari ' s sebastian vettel wins hungarian grand prix _END_
# 0.2727272727272727
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ leopard attacks fifth victim in mumbai ' s aarey _END_
# 0.2727272727272727
# _BEGIN_ ' navtej _END_
# _BEGIN_ twitter reacts to shashi tharoor ' s ' snollygoster ' tweet _END_
# 0.2727272727272727
# _BEGIN_ ' trans :# reports _END_
# _BEGIN_
END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ freedom 251 maker ' s director mohit goel detained for fraud _END_
# 0.23076923076923078
# _BEGIN_ index ' _END_
# _BEGIN_ another man claims getting ' churan lable ' notes from sbi atm _END_
# 0.23076923076923078
# _BEGIN_ index ' _END_
# _BEGIN_ disclose godse ' s statement in gandhi murder trial : cic _END_
# 0.23076923076923078
# _BEGIN_ index ' _END_
# _BEGIN_ cong complains to ec against bjp on sharmila ' s claim _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ probe kejriwal ' s nexus with militants in punjab : amarinder _END_
# 0.23076923076923078
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ uber taxi set on fire amidst ongoing cab drivers ' strike _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ amy jackson ' s phone hacked , personal photos leaked online _END_
# 0.23076923076923078
# _BEGIN_ dongre ' _END_
# _BEGIN_ hc stays aap govt ' s distance criteria for nursery admissions _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ flyer who opened flight ' s emergency exit released on surety _END_
# 0.23076923076923078
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ iaf to induct first indigenously developed ' eye in the sky ' _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ golfer escapes alligator ' s jaws by beating it by golf club _END_
# 0.23076923076923078
# _BEGIN_ srinu ' _END_
# _BEGIN_ dhoni recalls childhood days during visit to sehwag ' s school _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ don ' t sledge virat kohli , michael hussey tells australia _END_
# 0.23076923076923078
# _BEGIN_ ' hardy inability guys _END_
# _BEGIN_ ' men think intimidating women are not worth having sex with ' _END_
# 0.23076923076923078
# _BEGIN_ wolfsburg ' ryanair picked _END_
# _BEGIN_ ramdev can ' t make gay people straight : transgender model _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ ' healing ' garments made with herbs to be showcased at lfw _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ sachin says he changed playing style after waiter ' s advice _END_
# 0.23076923076923078
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ iran to block us visitors after trump ' s immigration ban _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ can ' t take kejriwal for granted , admits capt amarinder _END_
# 0.23076923076923078
# _BEGIN_ ' cuttack malappuram reports _END_
# _BEGIN_ was sexually assaulted at 14 : michael jackson ' s daughter _END_
# 0.23076923076923078
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ gandhi was once called ' half - naked fakir ' by churchill _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ pakistan ' s spy agency isi funding jallikattu violence : swamy _END_
# 0.23076923076923078
# _BEGIN_ ' viral ' ryanair reports _END_
# _BEGIN_ priyanka shows solidarity with anti - trump women ' s march _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ advocate moves court to get ' llb ' dropped from ' jolly llb 2 ' _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ lilly singh wins favourite youtube star at people ' s choice _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ ' cbfc replaces cuss word for slut with jhoothi in rangoon ' _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ fawad khan ' s wife shares 1st pic of daughter elayna _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ india ' s surgical strike was a responsible move : us _END_
# 0.23076923076923078
# _BEGIN_ ' trans :# reports _END_
# _BEGIN_ youtuber claims women in ' kiss prank ' video were his friends _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ deepika to appear on ' the ellen degeneres show ': reports _END_
# 0.23076923076923078
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ b ' luru molestation a conspiracy to defame city : minister _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ pakistan awards ' nishan - e - imtiaz ' to top military leaders _END_
# 0.23076923076923078
# _BEGIN_ ' officer its reports _END_
# _BEGIN_ woman makes man give to charity for calling her ' available ' _END_
# 0.23076923076923078
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ kohli named india ' s sportsperson of 2016 in india today poll _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ atc mixed an aircraft ' s location with another : aai _END_
# 0.23076923076923078
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ no du college gets highest grade in ugc ' s assessment _END_
# 0.23076923076923078
# _BEGIN_ ' trans :# reports _END_
# _BEGIN_ ngo starts ' wall of kindness ' for people living on pavements _END_
# 0.23076923076923078
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ police arrests prime accused in delhi ' s jamia nagar rape _END_
# 0.23076923076923078
# _BEGIN_ ' navtej _END_
# _BEGIN_ cashless economy a bigger dream than ' acche din ': akhilesh _END_
# 0.23076923076923078
# _BEGIN_ ' trans :# reports _END_
# _BEGIN_ berlin truck attack suspect shot dead in italy ' s milan _END_
# 0.23076923076923078
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ kohli named captain of cricket australia ' s test team of 2016 _END_
# 0.23076923076923078
# _BEGIN_ ' morning ' _END_
# _BEGIN_ poverty , illiteracy are manmohan ' s legacy : pm modi _END_
# 0.23076923076923078
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_
END_
# 0.23076923076923078
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ cisf security at delhi airport wins world ' s best award _END_
# 0.23076923076923078
# _BEGIN_ wolfsburg ' _END_
# ...
# 0.125
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ no one will hold tricolour if special status altered : j & k cm _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ 14 - yr - old girl raped twice in one night in uk , two arrested _END_
# 0.125
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ 3 held for robbing milk booth owner of ? 7 . 7l in ghaziabad _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ branson sells 31 % stake in virgin atlantic for ? 1 , 800 crore _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ if jd ( u ) against corruption , why allied with dad : tejashwi _END_
# 0.125
# _BEGIN_ williams bc _END_
# _BEGIN_ he has finally taken a stand : ex - bihar cm on nitish kumar _END_
# 0.125
# _BEGIN_ mandatorily ' ryanair picked _END_
# _BEGIN_ world no . _END_ _BEGIN_ 4 djokovic to miss us open , rest of 2017 season _END_
# 0.125
# _BEGIN_ completing agarsen _END_
# _BEGIN_ 4 - year - old girl dies after falling into a tea pan in delhi _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ sbi asked to refund ? 1 . 29 lakh to woman over stolen atm card _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ five - year - old girl fined ? 12 , 500 for running lemonade stall _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ armstrong ? s bag with traces of moon dust sells for ? 11 . UNK _END_
# 0.125
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ family of every martyr will get ? 1 crore in mp : cm chouhan _END_
# 0.125
# _BEGIN_ completing agarsen _END_
# _BEGIN_ 200 j & k kids evacuated in bullet - proof vans after pak firing _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ 50 % human rights complaints against armed forces in j & k : rti _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ stokes woke up at 3 : 30 in the morning to follow ipl auction _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ new ? 2 , 000 note not good for indian economy : baba ramdev _END_
# 0.125
# _BEGIN_ amlekhganj shahbad _END_
# _BEGIN_ sp provides UNK power to pm ' s lok sabha constituency : up cm _END_
# 0.125
# _BEGIN_ completing agarsen _END_
# _BEGIN_ if there ' s electricity on ramzan , it must be on diwali : modi _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ aussies will lose 0 - 3 if they play well vs india : harbhajan _END_
# 0.125
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ bjp leaders UNK off in ex - bihar dy cm sushil modi ? s UNK _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ lowest salary of govt employee rose over 32 , 000 % in 70 years _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ don ? t obstruct people in temple as they pray : hc to priests _END_
# 0.125
# _BEGIN_ ' trans :# reports _END_
# _BEGIN_ pm crossed limits of decency in his remark on manmohan : jd - u _END_
# 0.125
# _BEGIN_ ' trans :# reports _END_
# _BEGIN_ uk cleaning firm offers women ? 4 , 000 an hour to work nude _END_
# 0.125
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ inn UNK mein dum hai : ranbir on srk , big b , aamir , salman _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ williams sisters get richer by ? 28 . 8 cr after aus open final _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ us thought india will capture pok after 1971 b ? desh war : cia _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ srk is like my son : mother of man who died at raees promo _END_
# 0.125
# _BEGIN_ ' tailbone :# reports _END_
# _BEGIN_ hdfc bank sees lowest - ever profit growth at 15 % on note ban _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ man gets ? 70 , 000 in place of ? 3 , 500 from atm in rajasthan _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ modi not anti - muslim ; we must relook at triple talaq : jung _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ modi will run back to gujarat like a son of a rat : tmc mp _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ let , hizb - ul - mujahideen operating together in j & k : agencies _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ printing of ? 2 , 000 notes should be stopped in future : ramdev _END_
# 0.125
# _BEGIN_ completing agarsen _END_
# _BEGIN_ what guj achieved in UNK , we will do in a year : tn minister _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ nagpur to become wi - fi enabled city by march 2017 : maha cm _END_
# 0.125
# _BEGIN_ completing agarsen :# reports _END_
# _BEGIN_ i will give my best in new role , says rbi deputy guv acharya _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ air india carried 16 , 000 kg notes to remote areas in 32 days _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ after 3 yrs , delhi tableau to be showcased at r - day parade _END_
# 0.125
# _BEGIN_ srinu ' _END_
# _BEGIN_ ex - iaf chief sent to jail till dec 30 in vvip chopper scam _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ indian defence forces to be under us scrutiny , claims cpi ( m ) _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ republican party of india to seek ? UNK - cr loan waiver for scs _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ ravi shastri to be paid ? 7 crore per year as coach : reports _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ maha to pay farmers ? 2 . 43 cr per acre for land acquisition _END_
# 0.125
# _BEGIN_ williams bc _END_
# _BEGIN_ mithali raj registers joint - most 50 + scores in women ' s odis _END_
# 0.125
# _BEGIN_ amlekhganj ' _END_
# _BEGIN_ 3 new hospitals in delhi to add 3 , 200 beds by 2018 : jain _END_
# 0.125
# _BEGIN_ ' tailbone :# reports _END_
# _BEGIN_ company makes ? 17 , 000 gadget to tell users if they smell bad _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ 9 - year - old found dead in park with deep cuts and burn marks _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ 164 % rise in terror - related civilian deaths in j & k in a year _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ 99 % of delhi ? s dtc buses to be retired in 5 years _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ ? 10l compensation for j & k man used as human shield by army _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ up suffers ? 5 , 000 - crore loss post liquor ban along highways _END_
# 0.125
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ jd ( u ) slams modi for making cow an agenda to polarise votes _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ indian money in swiss banks hits record low of ? 4 , 500 crore _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ mtnl to repay ? 125 cr debt to public sector bank by june - end _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ not a single taint on my govt in three years : pm modi in us _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ sbi chief arundhati bhattacharya got ? 28 . UNK pay in 2016 - 17 _END_
# 0.125
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ delhi crime rate down by 31 %, cops solved 65 % cases in 2017 _END_
# 0.125
# _BEGIN_ srinu ' _END_
# _BEGIN_ just imagine yourself in grave : slain j & k cop wrote on fb _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ pics of rajinikanth , amy from 2 . 0 sets leaked online : report _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ recorded every meeting with trump as he may lie : ex - fbi boss _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ pm modi shows support for ? 1 , 000 cr mahabharata film : report _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ fire broke out on sets of bhoomi but no one got hurt : aditi _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ what is s - 400 missile system that india will buy from russia ? _END_
# 0.125
# _BEGIN_ amlekhganj shahbad _END_
# _BEGIN_ should ' ve covered legs when you met pm : fb user to priyanka _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ we are made for each other : pm modi on india - germany ties _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ when was last time india , pak faced off at un court icj ? _END_
# 0.125
# _BEGIN_ completing agarsen _END_
# _BEGIN_ aap ' s somnath bharti used to beat , harass wife : police to hc _END_
# 0.125
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ 3d film on ramayana to be made on budget of ? 500 cr : reports _END_
# 0.125
# _BEGIN_ azmi ' _END_
# _BEGIN_ muslims who join rss , bjp to be beaten : shahi imam of mosque _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ delhi cabbie who returned bag worth ? 8 lakh has ? 70 , 000 loan _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ ex - world no . 1 not welcome at wimbledon 2017 , say organisers _END_
# 0.125
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ first uk - china freight train completes 12 , 000 km in 20 days _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ not like i bought the car and took kriti for a ride : sushant _END_
# 0.125
# _BEGIN_ williams bc _END_
# _BEGIN_ kapil ' s a great comedian , he makes entire india laugh : sunil _END_
# 0.125
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ sonu shaved his head as he wanted to get rid of lice : UNK _END_
# 0.125
# _BEGIN_ srinu ' _END_
# _BEGIN_ being an accused in babri case not taint , but a tilak : uma _END_
# 0.125
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ old story all knew , no one talked about : comedian on tvf row _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ govt to seek info on deposits during note ban in i - t returns _END_
# 0.125
# _BEGIN_ amlekhganj shahbad _END_
# _BEGIN_ tn cm concerned about by - polls , not farmers ' cause : dmk _END_
# 0.125
# _BEGIN_ completing agarsen _END_
# _BEGIN_ at one point , i felt dizzy when mira was in labour : shahid _END_
# 0.125
# _BEGIN_ ' navtej _END_
# _BEGIN_ 22 - year - old rahat khan arrested for fb post on up cm yogi _END_
# 0.125
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ why no deposit window for old notes after dec 31 : sc to govt _END_
# 0.125
# _BEGIN_ amlekhganj ' _END_
# _BEGIN_ barca follow UNK comeback win with a 2 - 1 loss in la liga _END_
# 0.125
# _BEGIN_ srinu ' _END_
# _BEGIN_ navjot singh sidhu wins from amritsar ( east ) by 42 , 000 votes _END_
# 0.125
# _BEGIN_ srinu ' _END_
# _BEGIN_ we will win up , exit polls in bihar were wrong too : rahul _END_
# 0.125
# _BEGIN_ srinu ' _END_
# _BEGIN_ china can cede aksai chin if india does in east : ex - diplomat _END_
# 0.125
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ virat kohli is human , he had to fail one day : sourav ganguly _END_
# 0.125
# _BEGIN_ completing agarsen _END_
# _BEGIN_ attack planned on pm modi ' s life ahead of mau rally : police _END_
# 0.125
# _BEGIN_ amlekhganj shahbad _END_
# _BEGIN_ j & k cops ask pak high commission to claim let leader ' s body _END_
# 0.11764705882352941
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ over 21 lakh indians applied for h - 1b visa in 11 yrs : report _END_
# 0.11764705882352941
# _BEGIN_ completing agarsen bjp4delhi _END_
# _BEGIN_ ' what do i call you ? _END_ _BEGIN_ god ?' _END_ _BEGIN_ pak woman to swaraj after visa _END_
# 0.11764705882352941
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ 11 - yr - old tribal boy caught stealing ? 30 , hangs self in maha _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ 32 % vote share each for sena , bjp in bmc polls : exit poll _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ hitler ? s phone estimated at ? 1 . 3 -? 2 crore to be auctioned _END_
# 0.11764705882352941
# _BEGIN_ completing agarsen _END_
# _BEGIN_ if pm is up ? s adopted son then who is his father , asks lalu _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ if i join politics , me and my men will come with guns : kamal _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ i - t dept detects ? 16 , 200 crore in black money stashed abroad _END_
# 0.11764705882352941
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ up must get rid of scam - sp , cong , akhilesh & mayawati : pm _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ man stabs 5 - yr - old son who asked for ? 2 to buy kite _END_
# 0.11764705882352941
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ i - t dept UNK ? 1 , 550 cr black money from fraud entries _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ ? 3 - 4 l cr of evaded income deposited in banks after note ban _END_
# 0.11764705882352941
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ i - t department exposes fake kolkata firm , seizes ? 1 . 78 crore _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ azhar ali 1st pak test batsman to hit 2 200 + scores in a yr _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ will ask pm modi to give us jobs : wc - winning jr hockey team _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ how can a test end as drawn , not tied when scores are level ? _END_
# 0.11764705882352941
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ ? 60 cr cash , 245 kg gold seized at 10 airports post note ban _END_
# 0.11764705882352941
# _BEGIN_ amlekhganj shahbad _END_
# _BEGIN_ ? 2 , 000 notes to be phased out within 5 years : rss ideologue _END_
# 0.11764705882352941
# _BEGIN_ srinu ' _END_
# _BEGIN_ tata director had key role in ? 3 , 600 cr chopper scam : mistry _END_
# 0.11764705882352941
# _BEGIN_ akshaykumar ' _END_
# _BEGIN_ if my film flops , i talk , cry , get over it , move on : vidya _END_
# 0.11764705882352941
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ explain source of wealth or tejashwi must quit : jd ( u ) to rjd _END_
# 0.11764705882352941
# _BEGIN_ amlekhganj shahbad _END_
# _BEGIN_ i ' m not dating taapsee pannu , she ' s my dearest friend : saqib _END_
# 0.11764705882352941
# _BEGIN_ amlekhganj shahbad _END_
# _BEGIN_ 6 - yr - old offers piggy bank as bribe to find mother ' s killers _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ i fear for my life : rjd man who failed to defend lalu on tv _END_
# 0.11764705882352941
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ pm modi to meet donald trump for the 1st time on june 25 - 26 _END_
# 0.11764705882352941
# _BEGIN_ ' trans :# reports _END_
# _BEGIN_ it staff taken care of , no need for union : ex - infosys UNK _END_
# 0.11764705882352941
# _BEGIN_ index ' _END_
# _BEGIN_ will clear ? 25 , 000 crore debt by sept 30 : rcom tells lenders _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ my fees not even 10 % of what rumour says : pak lawyer at icj _END_
# 0.11764705882352941
# _BEGIN_ srinu ' _END_
# _BEGIN_ will cut your heads , hang them in j & k : militants to hurriyat _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ how does railways plan to earn extra ? 40 , 000 cr in 10 years ? _END_
# 0.11764705882352941
# _BEGIN_ williams bc _END_
# _BEGIN_ don ? t waste time , no vacancy for pm post till 2024 : paswan _END_
# 0.11764705882352941
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ give us evm for 72 hrs , will show how to rig it : kejriwal _END_
# 0.11764705882352941
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ aap must pay ? 97 cr for ads projecting kejriwal : delhi l - g _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ railways ordered to pay ? 1 . 3 lakh over bag lost 14 years ago _END_
# 0.11764705882352941
# _BEGIN_ index ' _END_
# _BEGIN_ want fresh look into $ 1 . 18 bn tata - docomo settlement : rbi _END_
# 0.11764705882352941
# _BEGIN_ ' navtej _END_
# _BEGIN_ benami act violators may face 7 years jail , fine : i - t dept _END_
# 0.11764705882352941
# _BEGIN_ wolfsburg ' _END_
# _BEGIN_ ? 56 crore cash , 1 . 98 lakh litres alcohol seized from up : ec _END_
# 0.1111111111111111
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ 97 % of old ? 500 , ? 1 , 000 notes back in banking system : report _END_
# 0.1111111111111111
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ alibaba paid $ 3 . 4 bn in taxes , created 30 mn jobs last year _END_
# 0.1111111111111111
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ smith 1st to score 1 , 000 + test runs in each of last 3 years _END_
# 0.1111111111111111
# _BEGIN_ ' navtej _END_
# _BEGIN_ UNK made $ 26 . 5 bn over 12 months , record for a us bank _END_
# 0.1111111111111111
# _BEGIN_ mandatorily ' _END_
# _BEGIN_ talk of 1 . 5 % rise in gdp rate due to gst rubbish : debroy _END_
# 0.1111111111111111
# _BEGIN_ bjp4delhi ' _END_
# _BEGIN_ i - t raids 22 places in ? 1 , 000 cr benami scam involving lalu _END_
# 0.1111111111111111
# _BEGIN_ williams bc _END_
# _BEGIN_ my lions are hungry , don ' t go near them : akhilesh to up cm _END_
# 0.1111111111111111
# _BEGIN_ index ' _END_
# _BEGIN_ drivers working for 6 hours a day earn up to ? 2 , 500 : uber _END_
# 0.1111111111111111
# _BEGIN_ ' navtej _END_
# _BEGIN_ ops didn ? t raise doubts on jaya ? s death when he was cm : dmk _END_
# 0.1111111111111111
# _BEGIN_ ' navtej _END_
# _BEGIN_ 3 iits made wasteful payments of ? 18 . 03 cr in 2015 - 16 : cag _END_
# 0.10526315789473684
# _BEGIN_ ' navtej _END_
# _BEGIN_ jaipur bank ceo goes missing after i - t raid , ? 1 . 56 cr seized _END_
# 0.10526315789473684
# _BEGIN_ ' navtej _END_
# _BEGIN_ 9 - year - old , 4 others attacked by gau rakshaks in j & k : report _END_
# 0.10526315789473684
