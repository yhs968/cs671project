# %% [markdown]
# # Load the Models

# %%
from modules.texts import Vocab, GloVeLoader
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import modules.extractive as ext
import modules.abstractive as abs
import modules.beam_search as bs
from modules.data import Documents
from torch.utils.data import DataLoader
import numpy as np

# Load the dataset
doc_file = './data/kaggle_news_rouge1.pkl'
docs = Documents(doc_file, vocab_size = 30000)
vocab = docs.vocab

d = 200
emb = nn.Embedding(vocab.V, d)
pretrained = emb
vocab_size = vocab.V
emb_size = emb.weight.data.size(1)
n_kernels = 50
kernel_sizes = [1,2,3,4,5]
sent_size = len(kernel_sizes) * n_kernels
hidden_size = 400
num_layers = 1
n_classes = len(docs.dclass2id)
batch_size = 1
torch.manual_seed(7)
torch.cuda.manual_seed(7)

ext_s_enc = ext.SentenceEncoder(vocab_size, emb_size,
                                   n_kernels, kernel_sizes, pretrained)
ext_d_enc = ext.DocumentEncoder(sent_size, hidden_size)
ext_extc = ext.ExtractorCell(sent_size, hidden_size)
ext_d_classifier = ext.DocumentClassifier(sent_size, n_classes)
abs_enc = abs.EncoderRNN(emb, hidden_size, num_layers)
abs_dec = abs.AttnDecoderRNN(emb, hidden_size * 2, num_layers)

# %%
# Load the models
from os.path import join

data_dir = join(os.path.expanduser('~'), 'cs671-large')
models = [emb, ext_s_enc, ext_d_enc, ext_extc, ext_d_classifier, abs_enc, abs_dec]
names = ['emb', 'ext_s_enc','ext_d_enc','ext_extc','ext_d_classifier','abs_enc','abs_dec']
epoch = 10
for name, model in zip(names, models):
    model.load_state_dict(torch.load(join(data_dir, name + '_epoch_%i' % epoch)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-52ebbc094ccb> in <module>()
#       7 epoch = 30
#       8 for name, model in zip(names, models):
# ----> 9     model.load_state_dict(torch.load(join(data_dir, name + '_epoch_%i' % epoch)))
#
# ~/anaconda3/envs/cs671/lib/python3.5/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     227     if isinstance(f, str) or (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     228         new_fd = True
# --> 229         f = open(f, 'rb')
#     230     try:
#     231         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/yhs/cs671-large/emb_epoch_30'

# %% [markdown]
# # Testing

# %%
from modules.test import Test

tester = Test(docs, models)
# Training accuracy
ext_acc, dclass_acc, r_score = tester.run(range(0, 3000), 20)

with open('./data/results%s.txt' % ('_hidden%i_nkernels%i' % (hidden_size, n_kernels)), 'w') as f:
    s1 = "Sentence Extraction Accuracy: %.3f" % ext_acc
    s2 = "Document Classification Accuracy: %.3f" % dclass_acc
    s3 = "Rouge Score: %.3f" % r_score
    f.write('\n'.join([s1,s2,s3]))
# Out:
# Sentence Extraction Accuracy: 0.559
# Document Classification Accuracy: 0.236
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-9cab131202a4> in <module>()
#       2
#       3 tester = Test(docs, models)
# ----> 4 ext_acc, dclass_acc, r_score = tester.run(range(0, 3000), 5)
#       5
#       6 with open('./data/results%s.txt' % ('_hidden%i_nkernels%i' % (hidden_size, n_kernels)), 'w') as f:
#
# ~/cs671project/src/modules/test.py in run(self, doc_indices, beam_size, verbose)
#      38         print("Sentence Extraction Accuracy: %.3f" % ext_acc)
#      39         print("Document Classification Accuracy: %.3f" % dclass_acc)
# ---> 40         r_score = self.rouge1(doc_indices, beam_size, verbose)
#      41
#      42         print("Sentence Extraction Accuracy: %.3f" % ext_acc)
#
# ~/cs671project/src/modules/test.py in rouge1(self, doc_indices, beam_size, verbose)
#     167                 n -= 1
#     168
# --> 169         rouge_score /= n
#     170
#     171         return rouge_score
#
# ZeroDivisionError: division by zero
