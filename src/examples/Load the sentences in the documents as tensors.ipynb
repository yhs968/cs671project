# %%
# Load the kaggle dataset from the pickle file

from modules.data import Documents

doc_file = './data/kaggle_news_rouge1.pkl'
docs = Documents(doc_file) # Vocabulary is automatically initialized.

# %%
# first document in the documents dataset
doc = docs[0]

# %%
# Load the sentences in the first document.
# Each sentences are represented by lists of word ids
for i in range(len(docs[0])):
    print(docs[0][i])
# Out:
# (
#  1544
#  1362
#   377
#   142
#   439
#    95
#   979
#  1491
#  1518
#    74
#   296
#  1361
#   169
#  1522
#  1292
#  1385
#  1380
#  1112
#   979
#   848
#   312
#   102
#  1362
#   991
#  1415
#    74
#   190
#   563
#   476
#   142
#  1482
#  1176
#   149
#   979
#  1266
#   874
#    24
#  1362
#  1432
#  1355
#    66
#  1198
#    95
#  1482
#   551
#  1385
#  1166
#  1519
#    51
#   654
#   967
#   727
#  1362
#   296
#  1361
#   834
#   728
#   328
#   548
#   729
#  1292
#  1385
#   268
#  1113
#   171
#  1528
#    24
#  1545
# [torch.LongTensor of size 68]
# ,
#  1
# [torch.LongTensor of size 1]
# )
# (
#  1544
#    66
#   728
#   620
#   206
#   389
#  1385
#   268
#  1362
#   529
#   967
#  1113
#   979
#   179
#    63
#    24
#  1545
# [torch.LongTensor of size 17]
# ,
#  1
# [torch.LongTensor of size 1]
# )
# (
#  1544
#   682
#  1371
#   338
#    20
#   121
#   972
#    33
#   402
#  1239
#  1144
#   984
#   142
#   268
#  1362
#   529
#   313
#   171
#    74
# ...

# %%
# The number of sentences in each documents
for d in docs:
    print(len(d))
# Out:
# 16
# 20
# 18
# 30
# 8
# 23
# 11
# 25
# 10
# 8
# 19
# 28
# 15
# 34
# 4
# 15
# 8
# 4
# 11
# 31
# 16
# 16
# 6
# 10
# 15
# 8
# 4
# 6
# 6
# 51
# 4
# 5
# 8
# 44
# 8
# 3
# 16
# 10
# 14
# 21
# 12
# 33
# 16
# 7
# 7
# 24
# 9
# 21
# 15
# 2
# 10
# 10
# 5
# 33
# 27
# 15
# 35
# 45
# 40
# 34
# 26
# 12
# 10
# 13
# 20
# 14
# 15
# 25
# 11
# 10
# 17
# 27
# 17
# 12
# 11
# 15
# 11
# 45
# 8
# 8
# 11
# 19
# 11
# 17
# 17
# 22
# 19
# 9
# 30
# 22
# 4
# 14
# 6
# 11
# 19
# 3
# 10
# 3
# 16
# 5
# 48
# 16
# 4
# 19
# 8
# 8
# 15
# 13
# 20
# 15
# 3
# 13
# 15
# 21
# 20
# 43
# 2
# 36
# 4
# 66
# 28
# 32
# 10
# 16
# 13
# 28
# 11
# 20
# 25
# 37
# 27
# 8
# 14
# 14
# 12
# 77
# 19
# 22
# 12
# 10
# 20
# 9
# 7
# 12
# 3
# 6
# 19
# 17
# 5
# 9
# 10
# 8
# 17
# 10
# 8
# 10
# 51
# 13
# 11
# 40
# 17
# 5
# 11
# 6
# 14
# 8
# 15
# 21
# 11
# 4
# 19
# 15
# 30
# 60
# 1
# 115
# 10
# 17
# 15
# 10
# 8
# 33
# 22
# 20
# 29
# 11
# 16
# 11
# 15
# 115
# 17
# 47
# 3
# 7
# 16
# 18
# 18
# 30
# 2
# 2
# 19
# 8
# 18
# 37
# 6
# 4
# 16
# 18
# 11
# 2
# 2
# ...
